# %% [markdown]
# #Data

# %%
# https://benchmark.ini.rub.de/gtsdb_dataset.html

# %% [markdown]
# #Train & Inference

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Faster-RCNN/Traffic-Sign-Detection/src/dataset
# !python txt_to_csv.py

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Faster-RCNN/Traffic-Sign-Detection/src/dataset
# !python split_train_valid.py

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Faster-RCNN/Traffic-Sign-Detection/src
# !python dataset.py

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Faster-RCNN/Traffic-Sign-Detection/src
# !python train.py

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Faster-RCNN/Traffic-Sign-Detection/src
# !python inference.py

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Faster-RCNN/Traffic-Sign-Detection/src
# !python inference_video.py
