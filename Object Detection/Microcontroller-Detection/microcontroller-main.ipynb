# %% [markdown]
# #Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install opendatasets

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Faster-RCNN/Microcontroller-Detection

import opendatasets as od
od.download("https://www.kaggle.com/datasets/tannergi/microcontroller-detection")
# {"username":"trinhngochuynh","key":"093feeac62560ebd0fd7d46449b59dda"}

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Faster-RCNN/Microcontroller-Detection/src
# !python dataset.py

# %% [markdown]
# #Train & Infer

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Faster-RCNN/Microcontroller-Detection/src
# !python engine.py

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Faster-RCNN/Microcontroller-Detection/src
# !python inference.py

# %% [markdown]
# #Test Something

# %%
import cv2
from google.colab.patches import cv2_imshow
image = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Faster-RCNN/Custom-Object-Detection/Microcontroller Detection/test/IMG_20181228_102636.jpg')

cv2_imshow(image)

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
